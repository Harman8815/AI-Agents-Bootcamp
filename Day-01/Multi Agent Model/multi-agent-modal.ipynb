# %%
import os
from kaggle_secrets import UserSecretsClient

try:
    GOOGLE_API_KEY = UserSecretsClient().get_secret("GOOGLE_API_KEY")
    os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY
    os.environ["GOOGLE_GENAI_USE_VERTEXAI"] = "FALSE"
    print("✅ Gemini API key setup complete.")
except Exception as e:
    print(f"🔑 Authentication Error: Please make sure you have added 'GOOGLE_API_KEY' to your Kaggle secrets. Details: {e}")

from google.adk.agents import Agent, SequentialAgent, ParallelAgent, LoopAgent
from google.adk.runners import InMemoryRunner
from google.adk.tools import AgentTool, FunctionTool, google_search
from google.genai import types

print("✅ ADK components imported successfully.")
# Out:
# ✅ Gemini API key setup complete.
# ✅ ADK components imported successfully.

# %% [markdown]
# # Sub Agents

# %%
# Research Agent: Its job is to use the google_search tool and present findings.
research_agent = Agent(
    name="ResearchAgent",
    model="gemini-2.5-flash-lite",
    instruction="""You are a specialized research agent. Your only job is to use the
    google_search tool to find 2-3 pieces of relevant information on the given topic and present the findings with citations.""",
    tools=[google_search],
    output_key="research_findings", # The result of this agent will be stored in the session state with this key.
)

print("✅ research_agent created.")
# Summarizer Agent: Its job is to summarize the text it receives.
summarizer_agent = Agent(
    name="SummarizerAgent",
    model="gemini-2.5-flash-lite",
    # The instruction is modified to request a bulleted list for a clear output format.
    instruction="""Read the provided research findings: {research_findings}
Create a concise summary as a bulleted list with 3-5 key points.""",
    output_key="final_summary",
)

print("✅ summarizer_agent created.")
# Out:
# ✅ research_agent created.
# ✅ summarizer_agent created.

# %%
# Root Coordinator: Orchestrates the workflow by calling the sub-agents as tools.
root_agent = Agent(
    name="ResearchCoordinator",
    model="gemini-2.5-flash-lite",
    # This instruction tells the root agent HOW to use its tools (which are the other agents).
    instruction="""You are a research coordinator. Your goal is to answer the user's query by orchestrating a workflow.
1. First, you MUST call the `ResearchAgent` tool to find relevant information on the topic provided by the user.
2. Next, after receiving the research findings, you MUST call the `SummarizerAgent` tool to create a concise summary.
3. Finally, present the final summary clearly to the user as your response.""",
    # We wrap the sub-agents in `AgentTool` to make them callable tools for the root agent.
    tools=[
        AgentTool(research_agent),
        AgentTool(summarizer_agent)
    ],
)

print("✅ editor_agent created.")
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug("What are the latest advancements in quantum computing and what do they mean for AI?")
# Out:
# ✅ editor_agent created.
#
#  ### Created new session: debug_session_id
#
# User > What are the latest advancements in quantum computing and what do they mean for AI?
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# ResearchCoordinator > The latest advancements in quantum computing are poised to revolutionize AI by enabling the solution of complex problems currently intractable for classical computers. Quantum machine learning algorithms could dramatically speed up AI's learning and adaptation processes, leading to faster training, improved optimization, and more efficient data processing. This also opens doors for AI to tackle problems in drug discovery, materials science, and complex system modeling. Quantum computers may also enable new AI approaches by identifying patterns inaccessible to classical algorithms. In the near future, hybrid systems combining quantum and classical computing are expected to be prevalent. While major tech companies are investing heavily, challenges in qubit stability, error correction, and scaling hardware persist.

# %% [markdown]
# # Sequential

# %%
print("✅ root_agent created.")
# Outline Agent: Creates the initial blog post outline.
outline_agent = Agent(
    name="OutlineAgent",
    model="gemini-2.5-flash-lite",
    instruction="""Create a blog outline for the given topic with:
    1. A catchy headline
    2. An introduction hook
    3. 3-5 main sections with 2-3 bullet points for each
    4. A concluding thought""",
    output_key="blog_outline", # The result of this agent will be stored in the session state with this key.
)

print("✅ outline_agent created.")
# Writer Agent: Writes the full blog post based on the outline from the previous agent.
writer_agent = Agent(
    name="WriterAgent",
    model="gemini-2.5-flash-lite",
    # The `{blog_outline}` placeholder automatically injects the state value from the previous agent's output.
    instruction="""Following this outline strictly: {blog_outline}
    Write a brief, 200 to 300-word blog post with an engaging and informative tone.""",
    output_key="blog_draft", # The result of this agent will be stored with this key.
)

print("✅ writer_agent created.")
# Editor Agent: Edits and polishes the draft from the writer agent.
editor_agent = Agent(
    name="EditorAgent",
    model="gemini-2.5-flash-lite",
    # This agent receives the `{blog_draft}` from the writer agent's output.
    instruction="""Edit this draft: {blog_draft}
    Your task is to polish the text by fixing any grammatical errors, improving the flow and sentence structure, and enhancing overall clarity.""",
    output_key="final_blog", # This is the final output of the entire pipeline.
)
# Out:
# ✅ root_agent created.
# ✅ outline_agent created.
# ✅ writer_agent created.

# %%
root_agent = SequentialAgent(
    name="BlogPipeline",
    sub_agents=[outline_agent, writer_agent, editor_agent],
)

print("✅ Sequential Agent created.")
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug("Write a blog post about the benefits of multi-agent systems for software developers")
# Out:
# ✅ Sequential Agent created.
#
#  ### Created new session: debug_session_id
#
# User > Write a blog post about the benefits of multi-agent systems for software developers
# OutlineAgent > ## Multi-Agent Systems: Your Software's New Secret Weapon
#
# **Introduction Hook:** Are you a software developer feeling overwhelmed by complexity? Do you dream of systems that can adapt, learn, and collaborate like a well-oiled team? It's time to unlock the power of Multi-Agent Systems (MAS) – a paradigm shift that's revolutionizing how we build intelligent and robust software.
#
# ---
#
# ### Section 1: What Exactly Are Multi-Agent Systems?
#
# *   **Definition in Simple Terms:** Imagine a group of independent software "agents," each with its own goals, knowledge, and decision-making capabilities, working together to achieve a common objective.
# *   **Key Characteristics:** Discuss autonomy, proactivity, reactivity, and social ability as core traits that make MAS so powerful.
# *   **Beyond Traditional Programming:** Highlight how MAS moves beyond single, monolithic programs to a more distributed and emergent approach to problem-solving.
#
# ### Section 2: The "Why" for Developers: Unlocking Key Benefits
#
# *   **Enhanced Modularity and Reusability:** Break down complex problems into smaller, manageable agent units that can be developed, tested, and reused independently.
# *   **Increased Robustness and Fault Tolerance:** If one agent fails, others can often pick up the slack, leading to more resilient systems that can continue operating even with partial failures.
# *   **Improved Scalability and Flexibility:** Easily add or remove agents to adapt to changing demands or expand system functionality without a complete overhaul.
#
# ### Section 3: Practical Advantages for Your Development Workflow
#
# *   **Handling Complex and Dynamic Environments:** MAS are ideal for situations where the environment is constantly changing or unpredictable, allowing for real-time adaptation and intelligent responses.
# *   **Facilitating Collaboration and Coordination:** Agents can negotiate, share information, and coordinate their actions, leading to more efficient and effective problem resolution, especially in distributed scenarios.
# *   **Enabling Emergent Behavior:** Complex, intelligent behavior can arise from the interactions of simpler agents, leading to solutions that might not have been explicitly programmed, fostering innovation.
#
# ### Section 4: Real-World Applications and Future Potential
#
# *   **From Robotics to Finance:** Briefly touch upon diverse applications like intelligent traffic control, supply chain management, game AI, financial trading, and more.
# *   **The Future is Collaborative:** Discuss how MAS is paving the way for more sophisticated AI, autonomous systems, and the Internet of Things (IoT).
#
# ---
#
# **Concluding Thought:** Embracing Multi-Agent Systems isn't just about adopting a new technology; it's about rethinking software architecture and unlocking a new level of intelligence, adaptability, and resilience for your projects. The future of software development is collaborative, and MAS is your ticket to join the conversation.
# WriterAgent > ## Multi-Agent Systems: Your Software's New Secret Weapon
#
# Feeling buried under the weight of complex software projects? Imagine building systems that don't just execute commands but learn, adapt, and even collaborate. This isn't science fiction; it's the reality of Multi-Agent Systems (MAS). MAS represents a fundamental shift, moving us from monolithic codebases to intelligent, distributed networks of software "agents."
#
# Think of MAS as assembling a crack team of specialists for your software. Each agent is an independent entity with its own goals, knowledge, and decision-making power. These agents are *autonomous*, acting on their own initiative; *proactive*, anticipating needs; *reactive*, responding to changes; and *socially capable*, interacting with others. This distributed approach breaks free from the limitations of traditional programming, offering powerful advantages.
#
# For developers, the benefits are immense. MAS dramatically enhances *modularity and reusability*, allowing you to break down complex problems into self-contained agent units. Systems become inherently more *robust and fault-tolerant* – if one agent falters, others can compensate. Crucially, MAS offers unparalleled *scalability and flexibility*, letting you add or remove agents to meet evolving demands. These systems excel in *dynamic environments*, facilitating seamless *collaboration and coordination*, and even enabling fascinating *emergent behavior* where complex intelligence arises organically from simple interactions.
#
# From optimizing supply chains to powering game AI, MAS is already making waves. It's the architecture of the future for AI, autonomous systems, and the IoT. Embracing MAS isn't just adopting a new tool; it's a strategic move towards building smarter, more resilient, and adaptable software.
# EditorAgent > ## Multi-Agent Systems: Your Software's New Secret Weapon for Developers
#
# Are you a software developer feeling overwhelmed by the sheer complexity of modern projects? Do you find yourself wishing your software could do more than just follow instructions – perhaps learn, adapt, or even work together like a seasoned team? If so, it's time to explore the transformative power of Multi-Agent Systems (MAS). This isn't just another buzzword; it represents a fundamental shift in how we design and build intelligent, robust software, moving us away from monolithic codebases towards dynamic, distributed networks of specialized "agents."
#
# ### What Exactly are Multi-Agent Systems?
#
# At its core, a Multi-Agent System is like assembling a highly skilled, specialized team for your software. Instead of a single, all-encompassing program, MAS consists of multiple independent software entities, or "agents." Each agent possesses its own unique goals, knowledge base, and decision-making capabilities. These agents are not just passive programs; they are characterized by:
#
# *   **Autonomy:** They can act independently, making their own decisions and taking initiative without constant human oversight.
# *   **Proactivity:** They can anticipate needs and take steps to achieve their goals before being explicitly told to.
# *   **Reactivity:** They can sense their environment and respond appropriately to changes and events.
# *   **Social Ability:** They can interact and communicate with other agents, cooperating, negotiating, or even competing to achieve objectives.
#
# This distributed approach fundamentally differs from traditional programming, offering a more flexible and intelligent way to tackle complex problems.
#
# ### The "Why" for Developers: Unlocking Key Benefits
#
# For software developers, the adoption of MAS unlocks a suite of compelling advantages that can significantly improve the development process and the final product:
#
# *   **Enhanced Modularity and Reusability:** MAS allows you to break down intricate problems into smaller, self-contained agent units. This modularity makes development, testing, and debugging much more manageable. Furthermore, individual agents or agent designs can often be reused across different projects, saving significant development time and effort.
# *   **Increased Robustness and Fault Tolerance:** In a monolithic system, a single point of failure can bring everything crashing down. With MAS, if one agent encounters an issue or fails, other agents can often detect this and compensate, ensuring the system as a whole can continue to operate. This inherent redundancy leads to far more resilient and fault-tolerant applications.
# *   **Improved Scalability and Flexibility:** Need to handle more load or add new functionality? With MAS, you can often simply add more agents or specialized agents to your system without requiring a complete architectural overhaul. Similarly, agents can be removed or updated as requirements change, offering unparalleled flexibility to adapt to evolving demands.
#
# ### Practical Advantages for Your Development Workflow
#
# Beyond the core benefits, MAS introduces practical advantages that directly impact how you build and manage software:
#
# *   **Handling Complex and Dynamic Environments:** MAS excels in scenarios where the environment is unpredictable or changes rapidly. Agents can be designed to sense these changes and adapt their behavior in real-time, making them ideal for applications like autonomous vehicles, robotics, or real-time market analysis.
# *   **Facilitating Collaboration and Coordination:** Complex tasks often require multiple components working in concert. Agents can be programmed to communicate, negotiate, and coordinate their actions. This is invaluable for distributed computing, where agents might need to share resources, delegate tasks, or agree on a common course of action.
# *   **Enabling Emergent Behavior:** One of the most fascinating aspects of MAS is the potential for emergent behavior. This is where complex, intelligent system-level actions arise organically from the simple interactions of many individual agents. It allows for novel solutions and sophisticated intelligence that might be incredibly difficult, if not impossible, to explicitly program.
#
# ### Real-World Applications and Future Potential
#
# Multi-Agent Systems are no longer confined to research labs. They are already powering a diverse range of applications, including:
#
# *   Optimizing complex supply chains and logistics.
# *   Creating realistic and challenging artificial intelligence in video games.
# *   Managing intelligent traffic control systems.
# *   Facilitating high-frequency trading in financial markets.
# *   Powering autonomous robots in manufacturing and exploration.
#
# As we move towards a future dominated by AI, autonomous systems, and the Internet of Things (IoT), the need for intelligent, distributed, and collaborative systems will only grow. MAS provides the foundational architecture for many of these advancements.
#
# ### The Future of Software is Collaborative
#
# Embracing Multi-Agent Systems isn't merely about adopting a new technology; it's about fundamentally rethinking software architecture. It's a strategic move towards building applications that are not just functional but also intelligent, resilient, and adaptable. If you're looking to tackle complexity head-on and build the next generation of sophisticated software, learning about and implementing MAS is an essential step. The future of software development is undeniably collaborative, and Multi-Agent Systems are your key to unlocking it.

# %% [markdown]
# # Parallel

# %%
# Tech Researcher: Focuses on AI and ML trends.
tech_researcher = Agent(
    name="TechResearcher",
    model="gemini-2.5-flash-lite",
    instruction="""Research the latest AI/ML trends. Include 3 key developments,
the main companies involved, and the potential impact. Keep the report very concise (100 words).""",
    tools=[google_search],
    output_key="tech_research", # The result of this agent will be stored in the session state with this key.
)

print("✅ tech_researcher created.")
# Health Researcher: Focuses on medical breakthroughs.
health_researcher = Agent(
    name="HealthResearcher",
    model="gemini-2.5-flash-lite",
    instruction="""Research recent medical breakthroughs. Include 3 significant advances,
their practical applications, and estimated timelines. Keep the report concise (100 words).""",
    tools=[google_search],
    output_key="health_research", # The result will be stored with this key.
)

print("✅ health_researcher created.")
# Finance Researcher: Focuses on fintech trends.
finance_researcher = Agent(
    name="FinanceResearcher",
    model="gemini-2.5-flash-lite",
    instruction="""Research current fintech trends. Include 3 key trends,
their market implications, and the future outlook. Keep the report concise (100 words).""",
    tools=[google_search],
    output_key="finance_research", # The result will be stored with this key.
)

print("✅ finance_researcher created.")
# The AggregatorAgent runs *after* the parallel step to synthesize the results.
aggregator_agent = Agent(
    name="AggregatorAgent",
    model="gemini-2.5-flash-lite",
    # It uses placeholders to inject the outputs from the parallel agents, which are now in the session state.
    instruction="""Combine these three research findings into a single executive summary:

    **Technology Trends:**
    {tech_research}
    
    **Health Breakthroughs:**
    {health_research}
    
    **Finance Innovations:**
    {finance_research}
    
    Your summary should highlight common themes, surprising connections, and the most important key takeaways from all three reports. The final summary should be around 200 words.""",
    output_key="executive_summary", # This will be the final output of the entire system.
)

print("✅ aggregator_agent created.")
# Out:
# ✅ tech_researcher created.
# ✅ health_researcher created.
# ✅ finance_researcher created.
# ✅ aggregator_agent created.

# %%
# The ParallelAgent runs all its sub-agents simultaneously.
parallel_research_team = ParallelAgent(
    name="ParallelResearchTeam",
    sub_agents=[tech_researcher, health_researcher, finance_researcher],
)

# This SequentialAgent defines the high-level workflow: run the parallel team first, then run the aggregator.
root_agent = SequentialAgent(
    name="ResearchSystem",
    sub_agents=[parallel_research_team, aggregator_agent],
)

print("✅ Parallel and Sequential Agents created.")
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug("Run the daily executive briefing on Tech, Health, and Finance")
# Out:
# ✅ Parallel and Sequential Agents created.
#
#  ### Created new session: debug_session_id
#
# User > Run the daily executive briefing on Tech, Health, and Finance
# HealthResearcher > Here's a summary of recent breakthroughs in Tech, Health, and Finance:
#
# **Technology:** AI and machine learning continue to advance rapidly, with applications in automation, image recognition, and natural language processing, powering tools like ChatGPT. The rollout of 5G networks is expanding connectivity, enabling innovations in autonomous systems and smart cities. Quantum computing is showing significant progress, with potential breakthroughs in cybersecurity and drug discovery expected within the next few years.
#
# **Health:** mRNA vaccine technology has revolutionized vaccine development, enabling faster creation of vaccines for various diseases. Advancements in Alzheimer's treatments include antibody therapies targeting amyloid plaques. At-home diagnostic tests, like those for COVID-19 and flu, are becoming more accessible, allowing for quicker diagnosis and treatment.
#
# **Finance:** Embedded finance is integrating financial services into non-financial platforms, streamlining transactions and payments. Decentralized finance (DeFi) is maturing with enhanced security and scalability in platforms like Aave and Uniswap. AI is increasingly used for personalization, risk assessment, and automating processes, with the AI in financial services market projected to double by 2029.
# TechResearcher > Here's a concise executive briefing on key trends in Tech, Health, and Finance for 2025:
#
# **Tech:**
# *   **Agentic AI & Generative AI:** AI that acts autonomously and sophisticated content generation are key. Companies like OpenAI, Google (Gemini), and Anthropic are leading this surge. This impacts everything from workflows to content creation, promising enhanced productivity and new creative possibilities.
# *   **Multimodal AI:** Systems capable of processing text, images, audio, and video simultaneously are becoming more prevalent. This enables more intuitive and versatile AI applications across platforms.
# *   **Spatial Computing:** Real-time simulations and immersive experiences are poised to reshape industries like healthcare and entertainment.
#
# **Health:**
# *   **AI in Diagnostics & Personalized Medicine:** AI is revolutionizing disease diagnosis and treatment personalization by analyzing vast datasets for early detection and tailored therapies.
# *   **Wearable Tech & Beyond (BCIs):** Advanced wearables and emerging brain-computer interfaces (BCIs) show promise for managing conditions like chronic pain and neurological disorders.
# *   **Gut Health & Microbiome Research:** Deeper understanding of the gut microbiome is leading to more sophisticated probiotics and prebiotics for overall well-being.
#
# **Finance:**
# *   **AI/ML for Automation & Efficiency:** AI and ML are integral to automated trading, fraud detection, personalized advice, and process automation, driving significant ROI. Major players include IBM and numerous fintech startups.
# *   **Digital-Only Banking & Fintech:** The rise of digital-only banks and innovative fintech solutions continues to disrupt traditional models, offering personalized experiences and competitive products.
# *   **Sustainability & ESG Focus:** Financial institutions are increasingly prioritizing sustainability efforts and ESG (Environmental, Social, and Governance) considerations.
# FinanceResearcher > **Tech Trends:**
#
# 1.  **Agentic AI and Context Engineering:** AI systems are evolving from simple chatbots to autonomous agents capable of complex tasks. This necessitates sophisticated "context engineering" to provide AI models with structured background information for reliable performance. The market implication is a demand for specialized AI developers and a shift in infrastructure orchestration to manage large AI workloads.
# 2.  **Hybrid Computing:** The integration of edge, cloud, and quantum computing is creating resilient IT architectures. This trend allows for optimized performance and security by leveraging the strengths of each computing model, impacting industries like manufacturing, healthcare, and finance by enabling real-time processing and advanced analytics.
# 3.  **AI Infrastructure Spending:** Despite economic concerns, major tech companies are significantly increasing capital investments in AI infrastructure, particularly GPUs. This surge fuels innovation but also creates demand for efficient orchestration strategies and skilled platform engineers to manage these complex AI workloads.
#
# **Health Trends:**
#
# 1.  **Personalized & Preventive Healthcare:** AI and data are driving highly personalized health plans, moving beyond precision medicine to address all aspects of a patient's needs. The market implication is a growing focus on proactive wellness and tailored patient engagement strategies.
# 2.  **Wearables 2.0 (BCIs & Implants):** The next frontier in wearable tech includes brain-computer interfaces and implants, showing promise for managing chronic conditions. Ethical considerations surrounding data ownership are significant market implications.
# 3.  **Mental Health & Neurodiversity Focus:** Increased social acceptance is driving investment in mental health training, apps, and resources. There's a growing understanding and acceptance of neurodiversity, leading to tailored support for conditions like ADHD and autism.
#
# **Finance Trends:**
#
# 1.  **AI Integration in Financial Systems:** AI is becoming central to financial operations, enhancing decision-making through data analytics and predictive modeling. Market implications include a demand for finance professionals with digital literacy and analytical skills.
# 2.  **Banking Consolidation:** Mega-mergers are reshaping the banking sector, aiming for more efficient and globally competitive institutions. This trend signals a more concentrated market with larger financial players.
# 3.  **Market Volatility & Investor Caution:** Global equity markets are experiencing volatility, with forecasts of potential corrections. This calls for heightened vigilance and data-backed decision-making, influencing investment strategies and risk management approaches.
#
# **Future Outlook:** Across all sectors, AI and advanced data analytics will continue to be transformative forces. Hybrid computing models will enable more resilient and efficient systems. In health, personalization and preventative care will be paramount, while finance will increasingly rely on intelligent automation and strategic insights to navigate a complex global landscape.
# AggregatorAgent > ## Executive Briefing: Tech, Health, and Finance Convergence
#
# The landscape across Tech, Health, and Finance is increasingly defined by the transformative power of **Artificial Intelligence**. From autonomous "agentic" AI and sophisticated generative capabilities to its application in diagnostics, personalized medicine, and financial automation, AI is driving unprecedented innovation and efficiency.
#
# A key theme is the **convergence of data and advanced computing**. Multimodal AI, processing diverse data types, and hybrid computing models (edge, cloud, quantum) are enabling more intuitive applications and resilient systems. This surge in AI is fueling significant investment in infrastructure, particularly GPUs.
#
# In **Health**, AI is revolutionizing personalized and preventive care, while advancements in wearables and brain-computer interfaces (BCIs) promise new ways to manage chronic conditions. **Finance** is experiencing a digital overhaul with the rise of fintech, embedded finance, and AI-driven automation, though market volatility necessitates cautious, data-informed strategies. The interconnectedness of these trends points to a future where intelligent, data-driven solutions will redefine productivity, well-being, and economic operations.

# %% [markdown]
# # Loop Workflow

# %%
# This agent runs ONCE at the beginning to create the first draft.
initial_writer_agent = Agent(
    name="InitialWriterAgent",
    model="gemini-2.5-flash-lite",
    instruction="""Based on the user's prompt, write the first draft of a short story (around 100-150 words).
    Output only the story text, with no introduction or explanation.""",
    output_key="current_story", # Stores the first draft in the state.
)

print("✅ initial_writer_agent created.")
# This agent's only job is to provide feedback or the approval signal. It has no tools.
critic_agent = Agent(
    name="CriticAgent",
    model="gemini-2.5-flash-lite",
    instruction="""You are a constructive story critic. Review the story provided below.
    Story: {current_story}
    
    Evaluate the story's plot, characters, and pacing.
    - If the story is well-written and complete, you MUST respond with the exact phrase: "APPROVED"
    - Otherwise, provide 2-3 specific, actionable suggestions for improvement.""",
    output_key="critique", # Stores the feedback in the state.
)

print("✅ critic_agent created.")
# Out:
# ✅ initial_writer_agent created.
# ✅ critic_agent created.

# %%
# This is the function that the RefinerAgent will call to exit the loop.
def exit_loop():
    """Call this function ONLY when the critique is 'APPROVED', indicating the story is finished and no more changes are needed."""
    return {"status": "approved", "message": "Story approved. Exiting refinement loop."}

print("✅ exit_loop function created.")
# Out:
# ✅ exit_loop function created.

# %%
# This agent refines the story based on critique OR calls the exit_loop function.
refiner_agent = Agent(
    name="RefinerAgent",
    model="gemini-2.5-flash-lite",
    instruction="""You are a story refiner. You have a story draft and critique.
    
    Story Draft: {current_story}
    Critique: {critique}
    
    Your task is to analyze the critique.
    - IF the critique is EXACTLY "APPROVED", you MUST call the `exit_loop` function and nothing else.
    - OTHERWISE, rewrite the story draft to fully incorporate the feedback from the critique.""",
    
    output_key="current_story", # It overwrites the story with the new, refined version.
    tools=[FunctionTool(exit_loop)], # The tool is now correctly initialized with the function reference.
)

print("✅ refiner_agent created.")
# Out:
# ✅ refiner_agent created.

# %%
# The LoopAgent contains the agents that will run repeatedly: Critic -> Refiner.
story_refinement_loop = LoopAgent(
    name="StoryRefinementLoop",
    sub_agents=[critic_agent, refiner_agent],
    max_iterations=2, # Prevents infinite loops
)

# The root agent is a SequentialAgent that defines the overall workflow: Initial Write -> Refinement Loop.
root_agent = SequentialAgent(
    name="StoryPipeline",
    sub_agents=[initial_writer_agent, story_refinement_loop],
)

print("✅ Loop and Sequential Agents created.")
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug("Write a short story about a lighthouse keeper who discovers a mysterious, glowing map")
# Out:
# ✅ Loop and Sequential Agents created.
#
#  ### Created new session: debug_session_id
#
# User > Write a short story about a lighthouse keeper who discovers a mysterious, glowing map
# InitialWriterAgent > Elias, keeper of the isolated Blackrock Light, traced the salt-worn lines on his worn oak table. The storm raged outside, a symphony of wind and wave against stone. A peculiar shimmer, not from the lamp's steady beam, caught his eye. It emanated from a rolled parchment he’d found tucked into a derelict lifeboat weeks ago. He’d dismissed it as old sailcloth, but tonight, it pulsed with an otherworldly light.
#
# Gingerly, he unfurled it. Intricate symbols, unlike any he'd ever seen, glowed with a soft, cerulean luminescence. They shifted and rearranged themselves, forming patterns that hinted at uncharted waters, at secrets buried deep beneath the restless sea. A chill, colder than the sea spray, traced its way up Elias’s spine. This was no ordinary map. This was an invitation.
# CriticAgent > This is a promising start to a story, setting a strong atmosphere and introducing a compelling mystery. Here are a few suggestions for improvement:
#
# 1.  **Expand on Elias's Character:** While we get a sense of Elias as a solitary, weathered keeper, giving him a brief moment of personal reflection or a hint of his past could deepen the reader's connection. For instance, does he yearn for adventure, or is he content in his isolation? A small detail revealing his inner world would make his reaction to the map more impactful.
#
# 2.  **Develop the Map's Nature:** The description of the map is evocative, but could be made more specific. What *kinds* of patterns does it hint at? Are they constellations, currents, or something more abstract? Providing a slightly more concrete (yet still mysterious) glimpse into the map's potential function or meaning would heighten the intrigue.
#
# 3.  **Enhance the "Invitation" Aspect:** The ending states it's an "invitation," but how does Elias perceive this? Is it a call to adventure, a warning, or something else entirely? Briefly showing Elias's *interpretation* or *feeling* about this invitation would provide a stronger hook for what might come next.
# RefinerAgent > Elias, keeper of the isolated Blackrock Light, traced the salt-worn lines on his worn oak table. The storm raged outside, a symphony of wind and wave against stone. He’d long since made peace with the crushing solitude, the rhythmic sweep of the beam his only companion. But tonight, a peculiar shimmer, not from the lamp's steady glow, caught his eye. It emanated from a rolled parchment he’d found tucked into a derelict lifeboat weeks ago. He’d dismissed it as brittle sailcloth, but it pulsed with an otherworldly light, a silent siren song against the tempest's roar.
#
# Gingerly, Elias unfurled it. Intricate symbols, unlike any constellations or currents he’d ever charted, glowed with a soft, cerulean luminescence. They shifted and rearranged themselves, coalescing into shapes that vaguely resembled swirling nebulae and deep-sea trenches. It wasn't a map of any known sea or sky; it was a map of the impossible, hinting at secrets buried deeper than any fathom, and perhaps, at places beyond the veil of the world he knew.
#
# A chill, colder than the sea spray that misted the lantern room glass, traced its way up Elias’s spine. He was a man of routine, of predictable tides and dependable stars. Yet, as the glowing patterns danced before his eyes, a forgotten ember of longing for the unknown, for a life beyond these stone walls, flickered within him. This was no ordinary chart. It was a beckoning, a whisper of adventure that resonated with a part of him he thought had long drowned in the lonely sea. It was an invitation, and for the first time in decades, Elias felt a tremor of anticipation, not fear, at what lay beyond the horizon.
# CriticAgent > APPROVED
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
